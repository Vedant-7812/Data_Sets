# %%
import numpy as np
import pandas as pd
df = pd.read_csv("bitcoin.csv")
print(df.head(10))
# Out:
#          Date      Open      High       Low     Close        Volume  \
# 0  2020-12-12  18051.32  18919.55  18046.04  18803.66  2.175258e+10
# 1  2020-12-11  18263.93  18268.45  17619.53  18058.90  2.791964e+10
# 2  2020-12-10  18553.30  18553.30  17957.07  18264.99  2.554713e+10
# 3  2020-12-09  18320.88  18626.29  17935.55  18553.92  3.442037e+10
# 4  2020-12-08  19191.53  19283.48  18269.95  18321.14  3.169229e+10
# 5  2020-12-07  19343.13  19411.83  18931.14  19191.63  2.689636e+10
# 6  2020-12-06  19154.18  19390.50  18897.89  19345.12  2.529378e+10
# 7  2020-12-05  18698.39  19160.45  18590.19  19154.23  2.724246e+10
# 8  2020-12-04  19446.97  19511.40  18697.19  18699.77  3.387239e+10
# 9  2020-12-03  19205.93  19566.19  18925.78  19445.40  3.193032e+10
#
#      Market Cap
# 0  3.491706e+11
# 1  3.353262e+11
# 2  3.391369e+11
# 3  3.444865e+11
# 4  3.401488e+11
# 5  3.562932e+11
# 6  3.591235e+11
# 7  3.555639e+11
# 8  3.471114e+11
# 9  3.609339e+11

# %%
#Q.2)
import numpy as np
import pandas as pd
df = pd.read_csv("bitcoin.csv")
print("Shape:", df.shape)
print("\nDataset Info:")
df.info()
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Shape: (2785, 7)
#
# Dataset Info:
# <class 'pandas.DataFrame'>
# RangeIndex: 2785 entries, 0 to 2784
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2785 non-null   str
#  1   Open        2785 non-null   float64
#  2   High        2785 non-null   float64
#  3   Low         2785 non-null   float64
#  4   Close       2785 non-null   float64
#  5   Volume      2785 non-null   float64
#  6   Market Cap  2785 non-null   float64
# dtypes: float64(6), str(1)
# memory usage: 152.4 KB
#
# Statistical Summary:
#                Open          High           Low         Close        Volume  \
# count   2785.000000   2785.000000   2785.000000   2785.000000  2.785000e+03
# mean    3979.724043   4079.344855   3874.920707   3986.352140  7.357466e+09
# std     4412.381770   4531.893292   4280.399549   4420.760384  1.206478e+10
# min       68.500000     74.560000     65.530000     68.430000  0.000000e+00
# ...

# %%
#Q.3)
import numpy as np
import pandas as pd
Df = pd.read_csv("bitcoin.csv")
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
#Q.4)
import numpy as np
import pandas as pd
Df = pd.read_csv("bitcoin.csv")
Num_cols = df.select_dtypes(include=['int64', 'float64']).columns
Cat_cols = df.select_dtypes(include=['object']).columns
print("Numerical Columns:")
print(list(Num_cols))
print("\nCategorical Columns:")
print(list(Cat_cols))
# Out:
# Numerical Columns:
# ['Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']
#
# Categorical Columns:
# ['Date']
# C:\Users\HP\AppData\Local\Temp\ipykernel_21232\76874549.py:6: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   Cat_cols = df.select_dtypes(include=['object']).columns

# %%
#Q.5)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Df = pd.read_csv("bitcoin.csv")
Num_cols = ['Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap']
for col in Num_cols:
    plt.figure(figsize=(3,3))
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
#Q.6)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Df = pd.read_csv("bitcoin.csv")
Df['Close'] = pd.to_datetime(df['Date']).dt.year
plt.figure(figsize=(6,4))
sns.countplot(x='Close', data=df)
plt.title("Bitcoin Records by Close")
plt.xlabel("Close")
plt.ylabel("Count")
plt.show()

# %%
#Q.7)
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
Df = pd.read_csv("bitcoin.csv")
corr = df[['Open','High','Low','Close','Volume','Market Cap']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Q.8

import numpy as np
import pandas as pd
df = pd.read_csv("bitcoin.csv")
print("Average Close Price:", df['Close'].mean())
print("Maximum Close Price:", df['Close'].max())
print("Minimum Close Price:", df['Close'].min())
print("\nAverage Close Price by Year:")
df['Year'] = pd.to_datetime(df['Date']).dt.year
print(df.groupby('Year')['Close'].mean())
# Out:
# Average Close Price: 3986.352140035907
# Maximum Close Price: 19625.84
# Minimum Close Price: 68.43
#
# Average Close Price by Year:
# Year
# 2013      257.973441
# 2014      527.236548
# 2015      272.453397
# 2016      568.492213
# 2017     4006.033616
# 2018     7572.298877
# 2019     7395.246630
# 2020    10411.988213
# Name: Close, dtype: float64

# %%
# Q.9
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("bitcoin.csv")
plt.figure(figsize=(4, 3))
sns.boxplot(y='Close', data=df)
plt.title("Boxplot of Close Price")
plt.show()
plt.figure(figsize=(4, 3))
sns.boxplot(y='Volume', data=df)
plt.title("Boxplot of Volume")
plt.show()

# %%
# Q.10
print("Average Open Price:", df['Open'].mean())
print("Average Close Price:", df['Close'].mean())
print("\nHighest Trading Volume:")
print(df['Volume'].max())
print("\nYear with Highest Average Close Price:")
print(df.groupby('Open')['Close'].mean().idxmax())
print("\nObservations:")
print("- Bitcoin prices generally increase over time.")
print("- Open, High, Low and Close prices are highly correlated.")
print("- Volume has some extreme values (outliers).")
print("- The heatmap shows a strong positive correlation among price-related columns.")
print("- Boxplots help identify unusual trading volume and price values.")
# Out:
# Average Open Price: 3979.724043087971
# Average Close Price: 3986.352140035907
#
# Highest Trading Volume:
# 74156772075.0
#
# Year with Highest Average Close Price:
# 18178.32
#
# Observations:
# - Bitcoin prices generally increase over time.
# - Open, High, Low and Close prices are highly correlated.
# - Volume has some extreme values (outliers).
# - The heatmap shows a strong positive correlation among price-related columns.
# - Boxplots help identify unusual trading volume and price values.
